# %%
# Read in the document-term matrix
import pandas as pd
import pickle

data = pd.read_pickle('dtm_stop.pkl')
data.head()
# Out:
#                    aaron  abandon  abandonment  abbas  abdication  abduction  \
# Barack Obama_2010      0        0            0      0           0          0
# Barack Obama_2011      0        1            0      0           0          0
# Barack Obama_2012      0        0            0      0           0          0
# Barack Obama_2013      0        0            0      0           0          0
# Barack Obama_2014      0        0            0      0           0          0
#
#                    abhorrent  abide  ability  abilityour  ...  zarfos  \
# Barack Obama_2010          0      1        1           0  ...       0
# Barack Obama_2011          0      0        0           0  ...       0
# Barack Obama_2012          0      0        0           0  ...       0
# Barack Obama_2013          0      0        3           0  ...       0
# Barack Obama_2014          0      0        0           0  ...       0
#
#                    zarqawi  zeitchik  zero  zeroemission  zerooverall  \
# Barack Obama_2010        0         0     0             0            0
# Barack Obama_2011        0         0     0             0            0
# Barack Obama_2012        0         0     0             0            0
# Barack Obama_2013        0         0     0             0            0
# Barack Obama_2014        0         0     1             0            0
#
#                    zimbabwe  zion  zone  zoom
# Barack Obama_2010         0     0     0     0
# Barack Obama_2011         0     0     0     0
# Barack Obama_2012         0     0     0     0
# Barack Obama_2013         0     0     0     0
# Barack Obama_2014         0     0     0     0
#
# [5 rows x 9927 columns]

# %%
# import gensim for LDA modeling
from gensim import matutils, models
# import scipy to process spare matrices
import scipy.sparse

# %%
# transpose the term document matrix
tdm = data.transpose()
tdm.head()
# Out:
#              Barack Obama_2010  Barack Obama_2011  Barack Obama_2012  \
# aaron                        0                  0                  0
# abandon                      0                  1                  0
# abandonment                  0                  0                  0
# abbas                        0                  0                  0
# abdication                   0                  0                  0
#
#              Barack Obama_2013  Barack Obama_2014  Barack Obama_2015  \
# aaron                        0                  0                  0
# abandon                      0                  0                  1
# abandonment                  0                  0                  0
# abbas                        0                  0                  0
# abdication                   0                  0                  0
#
#              Barack Obama_2016  Bill Clinton_1994  Bill Clinton_1995  \
# aaron                        0                  0                  0
# abandon                      0                  1                  0
# abandonment                  0                  0                  0
# abbas                        0                  0                  0
# abdication                   0                  0                  0
#
#              Bill Clinton_1996  ...  Richard M. Nixon_1971  \
# aaron                        0  ...                      0
# abandon                      3  ...                      0
# abandonment                  0  ...                      0
# abbas                        0  ...                      0
# abdication                   0  ...                      0
#
#              Richard M. Nixon_1972  Richard M. Nixon_1974  Ronald Reagan_1982  \
# aaron                            0                      0                   0
# abandon                          0                      1                   0
# abandonment                      0                      0                   0
# abbas                            0                      0                   0
# abdication                       0                      0                   0
#
#              Ronald Reagan_1983  Ronald Reagan_1984  Ronald Reagan_1985  \
# aaron                         0                   0                   0
# abandon                       0                   1                   1
# abandonment                   0                   0                   0
# abbas                         0                   0                   0
# abdication                    0                   0                   0
#
#              Ronald Reagan_1986  Ronald Reagan_1987  Ronald Reagan_1988
# aaron                         0                   0                   0
# abandon                       2                   1                   0
# abandonment                   1                   0                   0
# abbas                         0                   0                   0
# abdication                    0                   0                   0
#
# [5 rows x 52 columns]

# %%
# convert term document matrix to sparse matrix, then gensim corpus(part1)
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

# %%
# Gensim also requires dictionary of the all terms and their respective location in the term-document matrix
cv = pickle.load(open("cv_stop.pkl", "rb"))
id2word = dict((v, k) for k, v in cv.vocabulary_.items())

# %%
# for the lda model specify 2 topics and print out topic composition, do it 100 times
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=2, passes=100)
lda.print_topics()
# Out:
# [(0,
#   '0.004*"care" + 0.004*"health" + 0.004*"pass" + 0.004*"business" + 0.003*"citizen" + 0.003*"challenge" + 0.003*"worker" + 0.003*"strong" + 0.003*"protect" + 0.003*"act"'),
#  (1,
#   '0.004*"billion" + 0.003*"union" + 0.003*"percent" + 0.003*"growth" + 0.003*"problem" + 0.003*"defense" + 0.003*"believe" + 0.003*"rate" + 0.003*"power" + 0.003*"change"')]

# %%
# LDA for num_topics = 3
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=3, passes=100)
lda.print_topics()
# Out:
# [(0,
#   '0.005*"billion" + 0.003*"pass" + 0.003*"percent" + 0.003*"believe" + 0.003*"challenge" + 0.003*"crime" + 0.003*"care" + 0.003*"begin" + 0.003*"rate" + 0.003*"health"'),
#  (1,
#   '0.004*"business" + 0.004*"change" + 0.003*"health" + 0.003*"strong" + 0.003*"worker" + 0.003*"day" + 0.003*"pay" + 0.003*"power" + 0.003*"act" + 0.003*"lead"'),
#  (2,
#   '0.004*"weapon" + 0.003*"soviet" + 0.003*"propose" + 0.003*"act" + 0.003*"policy" + 0.002*"threat" + 0.002*"vietnam" + 0.002*"regime" + 0.002*"saddam" + 0.002*"hussein"')]

# %%
# LDA for num_topics = 4
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=4, passes=100)
lda.print_topics()
# Out:
# [(0,
#   '0.005*"billion" + 0.004*"growth" + 0.003*"policy" + 0.003*"vietnam" + 0.003*"defense" + 0.003*"propose" + 0.003*"end" + 0.003*"rate" + 0.003*"percent" + 0.003*"reduce"'),
#  (1,
#   '0.004*"states" + 0.004*"citizen" + 0.004*"iraq" + 0.004*"fight" + 0.003*"act" + 0.003*"health" + 0.003*"day" + 0.003*"law" + 0.003*"challenge" + 0.003*"weapon"'),
#  (2,
#   '0.005*"business" + 0.004*"care" + 0.004*"health" + 0.004*"pay" + 0.004*"pass" + 0.004*"change" + 0.003*"strong" + 0.003*"create" + 0.003*"century" + 0.003*"education"'),
#  (3,
#   '0.005*"billion" + 0.003*"act" + 0.003*"provide" + 0.003*"believe" + 0.003*"shall" + 0.003*"percent" + 0.003*"union" + 0.003*"think" + 0.003*"power" + 0.003*"problem"')]

# %% [markdown]
# <b>The LDA does need certain adjustments, however, there are some patterns that can be gauged from the model output. We can see that if number of topics is 3. Intuitively, there will be three topics: healthcare, workers, war.</b>

# %%
# In order to increase the accuracy of the topic models, we will pull out all nouns instead this time.
from nltk import word_tokenize, pos_tag

def nouns(text):
    '''Given a string of text, tokenize the text and pull out only the nouns.'''
    is_noun = lambda pos: pos[:2] == 'NN'
    tokenized = word_tokenize(text)
    all_nouns = [word for (word, pos) in pos_tag(tokenized) if is_noun(pos)] 
    return ' '.join(all_nouns)

# %%
# read in the clean data and apply the nouns function 
data_clean = pd.read_pickle('data_clean.pkl')
data_nouns = pd.DataFrame(data_clean.transcript.apply(nouns))
data_nouns[:4]
# Out:
#                                                           transcript
# Barack Obama_2010  madam speaker vice president member congress a...
# Barack Obama_2011  mr speaker vice president member congress amer...
# Barack Obama_2012  mr speaker vice president member congress amer...
# Barack Obama_2013  mr speaker vice president member congress citi...

# %%
# create a new document term matrix with nouns only
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# add stop words that will be removed based on previous models
add_stop_words = ['like', 'im', 'know', 'just', 'dont', 'thats', 'right', 'people',
                  'youre', 'got', 'gonna', 'time', 'think', 'yeah', 'said','applause','year','america',
                 'world','nation','americans','country','month','work','congress','government']
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# recreate the entirety of the document term matrix
cvn = CountVectorizer(stop_words=stop_words)
data_cvn = cvn.fit_transform(data_nouns.transcript)
data_dtmn = pd.DataFrame(data_cvn.toarray(), columns=cvn.get_feature_names())
data_dtmn.index = data_nouns.index
data_dtmn
# Out:
# George W. Bush_2003             0      0        1          0          0  ...
# George W. Bush_2004             0      0        0          0          0  ...
# George W. Bush_2005             0      0        0          0          1  ...
# George W. Bush_2006             0      0        0          0          0  ...
# George W. Bush_2007             0      0        0          0          0  ...
# George W. Bush_2008             0      0        4          0          0  ...
# Gerald Ford_1975                0      0        5          0          0  ...
# Gerald Ford_1976                0      0        3          0          0  ...
# Gerald Ford_1977                0      0        2          0          0  ...
# Jimmy Carter_1978               0      0        0          0          0  ...
# Jimmy Carter_1979               0      0        0          0          0  ...
# Jimmy Carter_1980               1      0        2          0          0  ...
# John F. Kennedy_1961            0      0        4          0          0  ...
# John F. Kennedy_1962            0      0        3          0          0  ...
# John F. Kennedy_1963            0      0        4          0          0  ...
# Lyndon B. Johnson_1964          0      0        2          0          1  ...
# Lyndon B. Johnson_1965          0      0        0          0          0  ...
# Lyndon B. Johnson_1966          0      0        1          0          0  ...
# Lyndon B. Johnson_1967          0      0        2          0          0  ...
# Lyndon B. Johnson_1968          0      0        2          0          0  ...
# Lyndon B. Johnson_1969          0      0        0          0          0  ...
# Richard M. Nixon_1970           0      0        1          0          0  ...
# Richard M. Nixon_1971           0      0        1          0          0  ...
# Richard M. Nixon_1972           0      0        1          0          0  ...
# Richard M. Nixon_1974           0      0        1          0          0  ...
# Ronald Reagan_1982              0      0        0          0          0  ...
# Ronald Reagan_1983              0      0        2          0          0  ...
# Ronald Reagan_1984              0      0        2          0          0  ...
# Ronald Reagan_1985              0      0        1          0          0  ...
# Ronald Reagan_1986              0      1        0          0          0  ...
# Ronald Reagan_1987              0      0        2          0          0  ...
# Ronald Reagan_1988              0      0        0          0          0  ...
#
#                         yugoslavia  zarfos  zarqawi  zeitchik  zero  \
# Barack Obama_2010                0       0        0         0     0
# Barack Obama_2011                0       0        0         0     0
# Barack Obama_2012                0       0        0         0     0
# Barack Obama_2013                0       0        0         0     0
# Barack Obama_2014                0       0        0         0     0
# Barack Obama_2015                0       0        0         0     1
# Barack Obama_2016                0       0        0         0     0
# Bill Clinton_1994                0       0        0         0     0
# Bill Clinton_1995                0       0        0         0     0
# Bill Clinton_1996                0       0        0         0     0
# Bill Clinton_1997                0       1        0         0     0
# Bill Clinton_1998                0       0        0         0     0
# Bill Clinton_1999                0       0        0         0     0
# Bill Clinton_2000                0       0        0         0     0
# Donald Trump_2018                0       0        0         0     0
# Donald Trump_2019                0       0        0         2     0
# George H.W. Bush_1990            0       0        0         0     0
# George H.W. Bush_1991            0       0        0         0     0
# George H.W. Bush_1992            0       0        0         0     0
# George W. Bush_2002              0       0        0         0     0
# George W. Bush_2003              0       0        0         0     0
# George W. Bush_2004              0       0        0         0     0
# George W. Bush_2005              0       0        1         0     0
# George W. Bush_2006              0       0        1         0     0
# George W. Bush_2007              0       0        1         0     0
# George W. Bush_2008              0       0        0         0     0
# Gerald Ford_1975                 0       0        0         0     0
# Gerald Ford_1976                 0       0        0         0     0
# Gerald Ford_1977                 0       0        0         0     0
# Jimmy Carter_1978                0       0        0         0     0
# Jimmy Carter_1979                0       0        0         0     0
# Jimmy Carter_1980                0       0        0         0     0
# John F. Kennedy_1961             0       0        0         0     0
columns]

# %%
# Create the gensim corpus
corpusn = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmn.transpose()))
# Create the vocabulary dictionary
id2wordn = dict((v, k) for k, v in cvn.vocabulary_.items())

# %%
# 2 topics 100 passes
ldan = models.LdaModel(corpus=corpusn, num_topics=2, id2word=id2wordn, passes=100)
ldan.print_topics()
# Out:
# [(0,
#   '0.012*"job" + 0.009*"family" + 0.009*"help" + 0.008*"child" + 0.007*"school" + 0.006*"economy" + 0.006*"community" + 0.006*"business" + 0.006*"tax" + 0.006*"support"'),
#  (1,
#   '0.011*"program" + 0.009*"peace" + 0.007*"help" + 0.007*"increase" + 0.007*"state" + 0.006*"war" + 0.006*"president" + 0.005*"budget" + 0.005*"effort" + 0.005*"tax"')]

# %%
# 3 topics 100 passes
ldan = models.LdaModel(corpus=corpusn, num_topics=3, id2word=id2wordn, passes=100)
ldan.print_topics()
# Out:
# [(0,
#   '0.010*"job" + 0.009*"help" + 0.009*"family" + 0.007*"child" + 0.006*"home" + 0.006*"community" + 0.006*"school" + 0.006*"program" + 0.006*"support" + 0.006*"state"'),
#  (1,
#   '0.009*"program" + 0.008*"help" + 0.007*"peace" + 0.007*"job" + 0.007*"economy" + 0.007*"tax" + 0.007*"state" + 0.006*"freedom" + 0.006*"security" + 0.006*"energy"'),
#  (2,
#   '0.007*"drug" + 0.007*"regime" + 0.006*"weapon" + 0.005*"hussein" + 0.005*"states" + 0.005*"saddam" + 0.005*"border" + 0.004*"terrorist" + 0.004*"terror" + 0.004*"woman"')]

# %%
# 4 topics 100 passes
ldan = models.LdaModel(corpus=corpusn, num_topics=4, id2word=id2wordn, passes=100)
ldan.print_topics()
# Out:
# [(0,
#   '0.014*"program" + 0.010*"peace" + 0.009*"increase" + 0.008*"state" + 0.007*"president" + 0.007*"effort" + 0.006*"help" + 0.006*"union" + 0.006*"budget" + 0.006*"war"'),
#  (1,
#   '0.000*"merit" + 0.000*"october" + 0.000*"substitution" + 0.000*"manufacturing" + 0.000*"yeari" + 0.000*"adequate" + 0.000*"worldand" + 0.000*"truck" + 0.000*"deteriorate" + 0.000*"underestimate"'),
#  (2,
#   '0.009*"freedom" + 0.008*"help" + 0.008*"security" + 0.007*"life" + 0.006*"tax" + 0.006*"war" + 0.006*"economy" + 0.006*"family" + 0.006*"man" + 0.006*"peace"'),
#  (3,
#   '0.013*"job" + 0.010*"family" + 0.010*"help" + 0.008*"child" + 0.007*"community" + 0.007*"school" + 0.007*"way" + 0.007*"business" + 0.006*"care" + 0.006*"home"')]

# %% [markdown]
# <b>The LDA with nouns only shows that under 3 topics, the talking points revolve around: Family, Economy, State</b>

# %%
# Furthur clean up the document term matrix, this time including adjectives as well as nouns
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)] 
    return ' '.join(nouns_adj)

# %%
# Apply the noun-adjective function
data_nouns_adj = pd.DataFrame(data_clean.transcript.apply(nouns_adj))

# %%
# Create a new dt matrix with only nouns and adjectives, remove common words with max_df
cvna = CountVectorizer(stop_words=stop_words, max_df=.8)
data_cvna = cvna.fit_transform(data_nouns_adj.transcript)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names())
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#                         aaron  abandon  abandonment  abdication  abduction  \
# Barack Obama_2010           0        0            0           0          0
# Barack Obama_2011           0        1            0           0          0
# Barack Obama_2012           0        0            0           0          0
# Barack Obama_2013           0        0            0           0          0
# Barack Obama_2014           0        0            0           0          0
# Barack Obama_2015           0        0            0           0          0
# Barack Obama_2016           0        0            0           0          0
# Bill Clinton_1994           0        1            0           0          0
# Bill Clinton_1995           0        0            0           0          0
# %%
# Create the gensim corpus
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

# Create the vocabulary dictionary
id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
# 2 topics 100 passes
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=100)
ldana.print_topics()
# Out:
# [(0,
#   '0.003*"administration" + 0.003*"soviet" + 0.002*"foreign" + 0.002*"inflation" + 0.002*"investment" + 0.002*"oil" + 0.002*"thing" + 0.002*"lead" + 0.002*"major" + 0.002*"price"'),
#  (1,
#   '0.004*"responsibility" + 0.003*"crime" + 0.003*"thank" + 0.003*"thing" + 0.003*"parent" + 0.003*"drug" + 0.003*"terrorist" + 0.002*"propose" + 0.002*"technology" + 0.002*"welfare"')]

# %%
# 3 topics 100 passes
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=100)
ldana.print_topics()
# Out:
# [(0,
#   '0.003*"inflation" + 0.003*"price" + 0.003*"propose" + 0.003*"major" + 0.003*"local" + 0.003*"area" + 0.003*"crime" + 0.002*"foreign" + 0.002*"income" + 0.002*"fund"'),
#  (1,
#   '0.006*"soviet" + 0.003*"control" + 0.003*"vietnam" + 0.003*"administration" + 0.003*"measure" + 0.003*"crime" + 0.003*"reduction" + 0.003*"resource" + 0.003*"report" + 0.003*"price"'),
#  (2,
#   '0.004*"thing" + 0.004*"terrorist" + 0.004*"parent" + 0.004*"thank" + 0.004*"lead" + 0.004*"college" + 0.003*"drug" + 0.003*"responsibility" + 0.003*"sure" + 0.003*"safe"')]

# %%
# 4 topics 100 passes
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=100)
ldana.print_topics()
# Out:
# [(0,
#   '0.006*"vietnam" + 0.004*"control" + 0.004*"measure" + 0.004*"crime" + 0.004*"try" + 0.003*"local" + 0.003*"price" + 0.003*"conflict" + 0.003*"soviet" + 0.003*"south"'),
#  (1,
#   '0.004*"thing" + 0.003*"responsibility" + 0.003*"hard" + 0.003*"college" + 0.003*"foreign" + 0.003*"propose" + 0.003*"administration" + 0.003*"inflation" + 0.003*"spending" + 0.003*"common"'),
#  (2,
#   '0.005*"terrorist" + 0.005*"thank" + 0.004*"parent" + 0.004*"drug" + 0.004*"iraq" + 0.004*"democracy" + 0.004*"lead" + 0.003*"safe" + 0.003*"technology" + 0.003*"weapon"'),
#  (3,
#   '0.004*"crime" + 0.004*"soviet" + 0.003*"measure" + 0.003*"reduction" + 0.002*"inflation" + 0.002*"present" + 0.002*"income" + 0.002*"administration" + 0.002*"area" + 0.002*"faith"')]

# %% [markdown]
# <b> If we were to use the noun-adj LDA model, we'd pick 2 topics, which covers two issues:state level challenges, community level challenges </b>

# %%
# Our final LDA model (for now) 
# question, why does the LDA generate different models every time?
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=100, random_state = 3)
ldana.print_topics()
# Out:
# [(0,
#   '0.003*"soviet" + 0.003*"crime" + 0.003*"price" + 0.003*"inflation" + 0.003*"major" + 0.003*"propose" + 0.003*"control" + 0.002*"local" + 0.002*"measure" + 0.002*"foreign"'),
#  (1,
#   '0.005*"thing" + 0.004*"parent" + 0.004*"college" + 0.004*"thank" + 0.003*"student" + 0.003*"lead" + 0.003*"responsibility" + 0.003*"company" + 0.003*"sure" + 0.003*"big"')]

# %%
# how to display the visualization of topics in this scenario?
# topics within each transcript
corpus_transformed = ldana[corpusna]

# %%
for i in corpus_transformed:
    print(i)
# Out:
# [(1, 0.99921936)]
# [(1, 0.99940443)]
# [(1, 0.9994515)]
# [(1, 0.99890375)]
# [(1, 0.99943995)]
# [(1, 0.9994429)]
# [(1, 0.99887586)]
# [(1, 0.99929357)]
# [(1, 0.9994505)]
# [(1, 0.9992661)]
# [(1, 0.9993671)]
# [(1, 0.9983998)]
# [(0, 0.029421981), (1, 0.9705781)]
# [(1, 0.9994254)]
# [(1, 0.99908537)]
# [(1, 0.99933666)]
# [(0, 0.33512986), (1, 0.6648701)]
# [(0, 0.91529787), (1, 0.084702104)]
# [(0, 0.4402993), (1, 0.55970067)]
# [(0, 0.72824866), (1, 0.27175134)]
# [(0, 0.9601388), (1, 0.03986127)]
# [(0, 0.6757214), (1, 0.32427862)]
# [(0, 0.7472402), (1, 0.25275984)]
# [(0, 0.7744619), (1, 0.22553803)]
# [(0, 0.8066107), (1, 0.1933893)]
# [(0, 0.6560495), (1, 0.3439505)]
# [(0, 0.9992938)]
# [(0, 0.9966027)]
# [(0, 0.9993411)]
# [(0, 0.99900675)]
# [(0, 0.9988607)]
# [(0, 0.99901384)]
# [(0, 0.9994936)]
# [(0, 0.9995291)]
# [(0, 0.9994276)]
# [(0, 0.99853176)]
# [(0, 0.99923044)]
# [(0, 0.999421)]
# [(0, 0.99975824)]
# [(0, 0.9996524)]
# [(0, 0.9995512)]
# [(0, 0.99911726)]
# [(0, 0.99905676)]
# [(0, 0.9990367)]
# [(0, 0.9989922)]
# [(0, 0.99906677)]
# [(0, 0.9438271), (1, 0.0561729)]
# [(0, 0.912169), (1, 0.08783103)]
# [(0, 0.88848704), (1, 0.11151296)]
# [(0, 0.9407168), (1, 0.059283227)]
# [(0, 0.9205425), (1, 0.07945749)]
# [(0, 0.96341616), (1, 0.03658382)]

# %%
data_dtmna.index
# Out:
# Index(['Barack Obama_2010', 'Barack Obama_2011', 'Barack Obama_2012',
#        'Barack Obama_2013', 'Barack Obama_2014', 'Barack Obama_2015',
#        'Barack Obama_2016', 'Bill Clinton_1994', 'Bill Clinton_1995',
#        'Bill Clinton_1996', 'Bill Clinton_1997', 'Bill Clinton_1998',
#        'Bill Clinton_1999', 'Bill Clinton_2000', 'Donald Trump_2018',
#        'Donald Trump_2019', 'George H.W. Bush_1990', 'George H.W. Bush_1991',
#        'George H.W. Bush_1992', 'George W. Bush_2002', 'George W. Bush_2003',
#        'George W. Bush_2004', 'George W. Bush_2005', 'George W. Bush_2006',
#        'George W. Bush_2007', 'George W. Bush_2008', 'Gerald Ford_1975',
#        'Gerald Ford_1976', 'Gerald Ford_1977', 'Jimmy Carter_1978',
#        'Jimmy Carter_1979', 'Jimmy Carter_1980', 'John F. Kennedy_1961',
#        'John F. Kennedy_1962', 'John F. Kennedy_1963',
#        'Lyndon B. Johnson_1964', 'Lyndon B. Johnson_1965',
#        'Lyndon B. Johnson_1966', 'Lyndon B. Johnson_1967',
#        'Lyndon B. Johnson_1968', 'Lyndon B. Johnson_1969',
#        'Richard M. Nixon_1970', 'Richard M. Nixon_1971',
#        'Richard M. Nixon_1972', 'Richard M. Nixon_1974', 'Ronald Reagan_1982',
#        'Ronald Reagan_1983', 'Ronald Reagan_1984', 'Ronald Reagan_1985',
#        'Ronald Reagan_1986', 'Ronald Reagan_1987', 'Ronald Reagan_1988'],
#       dtype='object')
